# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import datetime as dt
import json
from six.moves.urllib.request import urlopen

# %% [markdown]
# # 2. Collect the datasets of DublinBikes system

# %% [markdown]
# ##2.1. Get the list of Bike Stations

# %%
# UPDATE:
# From 26/8/2021, the API https://dublinbikes.staging.derilinx.com/api/v1
# has been shut down. You can not get data from the API.
# So please go to the new site to collect the data from the .CSV files:
# https://data.smartdublin.ie/dataset/dublinbikes-api


# Get the list of Bike Stations
url = 'https://dublinbikes.staging.derilinx.com/api/v1/resources/stations'

urlResponse = urlopen(url)

if hasattr(urlResponse.headers, 'get_content_charset'):
    encoding = urlResponse.headers.get_content_charset('utf-8')
else:
    encoding = urlResponse.headers.getparam('charset') or 'utf-8'

data = json.loads(urlResponse.read().decode(encoding))
stations_df = pd.DataFrame.from_dict(data, orient="columns")

# %%
# Remove the Bike Station as a Terminal for testing
stations_df.drop(stations_df.tail(1).index, inplace=True)

# Remove irrelevant columns
stations_df.drop(columns={'st_CONTRACTNAME'}, inplace=True)

# Standardize the column names
stations_df.rename(columns={'st_ADDRESS':'address', 'st_ID':'station_id', \
                      'st_LATITUDE':'latitude', 'st_LONGITUDE':'longitude', \
                      'st_NAME':'name'}, inplace=True)

stations_df
# Out:
#                    address  station_id  ...  longitude                   name
# 0            Clarendon Row           1  ...  -6.262501          CLARENDON ROW
# 1       Blessington Street           2  ...  -6.268140     BLESSINGTON STREET
# 2            Bolton Street           3  ...  -6.269859          BOLTON STREET
# 3             Greek Street           4  ...  -6.272976           GREEK STREET
# 4        Charlemont Street           5  ...  -6.260177       CHARLEMONT PLACE
# ..                     ...         ...  ...        ...                    ...
# 111   Merrion Square South         113  ...  -6.248606   MERRION SQUARE SOUTH
# 112  Wilton Terrace (Park)         114  ...  -6.248345  WILTON TERRACE (PARK)
# 113       Killarney Street         115  ...  -6.247579       KILLARNEY STREET
# 114             Broadstone         116  ...  -6.272314             BROADSTONE
# 115      Hanover Quay East         117  ...  -6.231755      HANOVER QUAY EAST
#
# [116 rows x 5 columns]

# %% [markdown]
# ##2.2. Define the function to get the historical data of a Bike Station from API

# %%
# UPDATE:
# From 26/8/2021, the API https://dublinbikes.staging.derilinx.com/api/v1
# has been shut down. You can not get data from the API.
# So please go to the new site to collect the data from the .CSV files:
# https://data.smartdublin.ie/dataset/dublinbikes-api


def getDataOfAStation(_dfrom, _dto, _stationId):
  url = 'https://dublinbikes.staging.derilinx.com/api/v1/resources/historical/?dfrom=' \
  + _dfrom + '&dto=' + _dto + '&station=' + _stationId

  urlResponse = urlopen(url)
  if hasattr(urlResponse.headers, 'get_content_charset'):
      encoding = urlResponse.headers.get_content_charset('utf-8')
  else:
      encoding = urlResponse.headers.getparam('charset') or 'utf-8'

  data = json.loads(urlResponse.read().decode(encoding))
  if (len(data) > 0):
    if ('historic' in data[0]):
      df = pd.DataFrame.from_dict(data[0]['historic'], orient="columns")
      df.insert(loc=0, column='station_id', value = _stationId)
      if ('latitude' in data[0]):
        df.insert(loc=1, column='latitude', value = data[0]['latitude'])
      else:
        df.insert(loc=1, column='latitude', value = '')
      if ('longitude' in data[0]):  
        df.insert(loc=2, column='longitude', value = data[0]['longitude'])
      else:
        df.insert(loc=1, column='longitude', value = '')
      return df
  else:
    return None

# %% [markdown]
# ## 2.3. Define a function to standardize the datetime value

# %%
# 1. Split datetime string into date, hour, minute variables

# 2. To merge the historic Bike-availability data with the Weather, Covid data,
# we need to create a field "time_interval" with format: YYYYMMDDHHmm
# YYYY: Year; MM: Month; DD: Day; HH: Hour; mm: Minute
# Notes: mm with 5-minute interval (i.e., 00, 05, 10, ..., 55)

def transform_data(_df):
  _df['date'] = _df['time'].apply(lambda x: x[0:4] + x[5:7] + x[8:10])
  _df['hour'] = _df['time'].apply(lambda x: x[11:13])
  _df['minute'] = _df['time'].apply \
    (lambda x: \
      str(int(x[14:16]) - (int(x[14:16])%5)) \
      if (x[14] != '0') \
      else  '0'+str(int(x[14:16]) - (int(x[14:16])%5))
    )

  _df['time_interval'] = _df['date'] + _df['hour'] + _df['minute']
  _df.drop(columns=['time'], inplace=True)
  return _df

# %% [markdown]
# ##2.4. Define a function to loop all Bike Stations for getting data

# %%
def getDataAllStations(_stations, _dfrom, _dto):
  # Get data of the 1st Bike Station
  stationId = str(_stations.iloc[0]['station_id'])
  _df = getDataOfAStation(_dfrom, _dto, stationId)
  if _df is None:
    print('No data of the stationID =',stationId, 'between', _dfrom, 'and', _dto)
  else:
    _df = transform_data(_df)
    
  # Loop others in the list of Bike Station
  for i in range(1,len(_stations)):
    stationId = str(_stations.loc[i,'station_id'])
    print('index =',i,'. Getting data of the StationId =', stationId)
    while True:
      try:
        temp_df = getDataOfAStation(_dfrom, _dto, stationId)
        if temp_df is None:
          break
        else:
          temp_df = transform_data(temp_df)
        break
      except:
        print('API time out. Retrying...')
    if temp_df is None:
      print('No data of the stationID =',stationId, 'between', _dfrom, 'and', _dto)
    else:
      _df = pd.concat([_df, temp_df], ignore_index=True)
  return _df

# %% [markdown]
# ##2.4. Get historical data for all Bike Stations

# %% [markdown]
# 2.4.1. Datasets of the Quarter 1 & 2 in 2020

# %%
# Get data from 01/01/2020 to 30/06/2020
dfrom = '201912312359'
dto = '202006302359'

df = getDataAllStations(stations_df, dfrom, dto)

# Save data into a file (It's stored in Google Drive for later analysis)
df.to_csv('drive/MyDrive/dublinbikes/datasets/dublinbikes_2020_Quarter_1_2.csv', index=False)
# Out:
# No data of the stationID = 1 between 201912312359 and 202006302359
# index = 1 . Getting data of the StationId = 2
# index = 2 . Getting data of the StationId = 3
# index = 3 . Getting data of the StationId = 4
# index = 4 . Getting data of the StationId = 5
# index = 5 . Getting data of the StationId = 6
# index = 6 . Getting data of the StationId = 7
# index = 7 . Getting data of the StationId = 8
# index = 8 . Getting data of the StationId = 9
# index = 9 . Getting data of the StationId = 10
# index = 10 . Getting data of the StationId = 11
# index = 11 . Getting data of the StationId = 12
# index = 12 . Getting data of the StationId = 13
# index = 13 . Getting data of the StationId = 14
# No data of the stationID = 14 between 201912312359 and 202006302359
# index = 14 . Getting data of the StationId = 15
# index = 15 . Getting data of the StationId = 16
# index = 16 . Getting data of the StationId = 17
# index = 17 . Getting data of the StationId = 18
# index = 18 . Getting data of the StationId = 19
# index = 19 . Getting data of the StationId = 21
# index = 20 . Getting data of the StationId = 22
# index = 21 . Getting data of the StationId = 23
# index = 22 . Getting data of the StationId = 24
# index = 23 . Getting data of the StationId = 25
# index = 24 . Getting data of the StationId = 26
# index = 25 . Getting data of the StationId = 27
# index = 26 . Getting data of the StationId = 28
# index = 27 . Getting data of the StationId = 29
# index = 28 . Getting data of the StationId = 30
# index = 29 . Getting data of the StationId = 31
# index = 30 . Getting data of the StationId = 32
# index = 31 . Getting data of the StationId = 33
# API time out. Retrying...
# index = 32 . Getting data of the StationId = 34
# index = 33 . Getting data of the StationId = 35
# No data of the stationID = 35 between 201912312359 and 202006302359
# index = 34 . Getting data of the StationId = 36
# index = 35 . Getting data of the StationId = 37
# index = 36 . Getting data of the StationId = 38
# index = 37 . Getting data of the StationId = 39
# index = 38 . Getting data of the StationId = 40
# index = 39 . Getting data of the StationId = 41
# index = 40 . Getting data of the StationId = 42
# index = 41 . Getting data of the StationId = 43
# index = 42 . Getting data of the StationId = 44
# index = 43 . Getting data of the StationId = 45
# index = 44 . Getting data of the StationId = 46
# No data of the stationID = 46 between 201912312359 and 202006302359
# index = 45 . Getting data of the StationId = 47
# index = 46 . Getting data of the StationId = 48
# index = 47 . Getting data of the StationId = 49
# index = 48 . Getting data of the StationId = 50
# index = 49 . Getting data of the StationId = 51
# index = 50 . Getting data of the StationId = 52
# index = 51 . Getting data of the StationId = 53
# index = 52 . Getting data of the StationId = 54
# index = 53 . Getting data of the StationId = 55
# index = 54 . Getting data of the StationId = 56
# index = 55 . Getting data of the StationId = 57
# index = 56 . Getting data of the StationId = 58
# index = 57 . Getting data of the StationId = 59
# index = 58 . Getting data of the StationId = 60
# No data of the stationID = 60 between 201912312359 and 202006302359
# index = 59 . Getting data of the StationId = 61
# index = 60 . Getting data of the StationId = 62
# index = 61 . Getting data of the StationId = 63
# index = 62 . Getting data of the StationId = 64
# index = 63 . Getting data of the StationId = 65
# index = 64 . Getting data of the StationId = 66
# index = 65 . Getting data of the StationId = 67
# index = 66 . Getting data of the StationId = 68
# index = 67 . Getting data of the StationId = 69
# index = 68 . Getting data of the StationId = 70
# No data of the stationID = 70 between 201912312359 and 202006302359
# index = 69 . Getting data of the StationId = 71
# index = 70 . Getting data of the StationId = 72
# index = 71 . Getting data of the StationId = 73
# index = 72 . Getting data of the StationId = 74
# index = 73 . Getting data of the StationId = 75
# index = 74 . Getting data of the StationId = 76
# index = 75 . Getting data of the StationId = 77
# index = 76 . Getting data of the StationId = 78
# index = 77 . Getting data of the StationId = 79
# index = 78 . Getting data of the StationId = 80
# index = 79 . Getting data of the StationId = 81
# index = 80 . Getting data of the StationId = 82
# index = 81 . Getting data of the StationId = 83
# index = 82 . Getting data of the StationId = 84
# index = 83 . Getting data of the StationId = 85
# index = 84 . Getting data of the StationId = 86
# index = 85 . Getting data of the StationId = 87
# index = 86 . Getting data of the StationId = 88
# index = 87 . Getting data of the StationId = 89
# API time out. Retrying...
# index = 88 . Getting data of the StationId = 90
# index = 89 . Getting data of the StationId = 91
# index = 90 . Getting data of the StationId = 92
# index = 91 . Getting data of the StationId = 93
# index = 92 . Getting data of the StationId = 94
# index = 93 . Getting data of the StationId = 95
# index = 94 . Getting data of the StationId = 96
# index = 95 . Getting data of the StationId = 97
# index = 96 . Getting data of the StationId = 98
# index = 97 . Getting data of the StationId = 99
# index = 98 . Getting data of the StationId = 100
# index = 99 . Getting data of the StationId = 101
# index = 100 . Getting data of the StationId = 102
# index = 101 . Getting data of the StationId = 103
# index = 102 . Getting data of the StationId = 104
# index = 103 . Getting data of the StationId = 105
# index = 104 . Getting data of the StationId = 106
# index = 105 . Getting data of the StationId = 107
# index = 106 . Getting data of the StationId = 108
# index = 107 . Getting data of the StationId = 109
# index = 108 . Getting data of the StationId = 110
# index = 109 . Getting data of the StationId = 111
# index = 110 . Getting data of the StationId = 112
# index = 111 . Getting data of the StationId = 113
# index = 112 . Getting data of the StationId = 114
# index = 113 . Getting data of the StationId = 115
# index = 114 . Getting data of the StationId = 116
# index = 115 . Getting data of the StationId = 117

# %% [markdown]
# 2.4.2. Datasets of the Quarter 3 & 4 in 2020

# %%
# Get data from 01/07/2020 to 31/12/2020
dfrom = '202006302359'
dto = '202012312359'

df = getDataAllStations(stations_df, dfrom, dto)

# Save data into a file (It's stored in Google Drive for later analysis)
df.to_csv('drive/MyDrive/dublinbikes/datasets/dublinbikes_2020_Quarter_3_4.csv', index=False)
# Out:
# No data of the stationID = 1 between 202006302359 and 202012312359
# index = 1 . Getting data of the StationId = 2
# index = 2 . Getting data of the StationId = 3
# index = 3 . Getting data of the StationId = 4
# index = 4 . Getting data of the StationId = 5
# index = 5 . Getting data of the StationId = 6
# index = 6 . Getting data of the StationId = 7
# index = 7 . Getting data of the StationId = 8
# index = 8 . Getting data of the StationId = 9
# index = 9 . Getting data of the StationId = 10
# index = 10 . Getting data of the StationId = 11
# index = 11 . Getting data of the StationId = 12
# index = 12 . Getting data of the StationId = 13
# index = 13 . Getting data of the StationId = 14
# No data of the stationID = 14 between 202006302359 and 202012312359
# index = 14 . Getting data of the StationId = 15
# index = 15 . Getting data of the StationId = 16
# index = 16 . Getting data of the StationId = 17
# index = 17 . Getting data of the StationId = 18
# index = 18 . Getting data of the StationId = 19
# index = 19 . Getting data of the StationId = 21
# index = 20 . Getting data of the StationId = 22
# index = 21 . Getting data of the StationId = 23
# index = 22 . Getting data of the StationId = 24
# index = 23 . Getting data of the StationId = 25
# index = 24 . Getting data of the StationId = 26
# index = 25 . Getting data of the StationId = 27
# index = 26 . Getting data of the StationId = 28
# index = 27 . Getting data of the StationId = 29
# index = 28 . Getting data of the StationId = 30
# index = 29 . Getting data of the StationId = 31
# index = 30 . Getting data of the StationId = 32
# index = 31 . Getting data of the StationId = 33
# index = 32 . Getting data of the StationId = 34
# index = 33 . Getting data of the StationId = 35
# No data of the stationID = 35 between 202006302359 and 202012312359
# index = 34 . Getting data of the StationId = 36
# index = 35 . Getting data of the StationId = 37
# index = 36 . Getting data of the StationId = 38
# index = 37 . Getting data of the StationId = 39
# index = 38 . Getting data of the StationId = 40
# index = 39 . Getting data of the StationId = 41
# index = 40 . Getting data of the StationId = 42
# index = 41 . Getting data of the StationId = 43
# index = 42 . Getting data of the StationId = 44
# index = 43 . Getting data of the StationId = 45
# index = 44 . Getting data of the StationId = 46
# No data of the stationID = 46 between 202006302359 and 202012312359
# index = 45 . Getting data of the StationId = 47
# index = 46 . Getting data of the StationId = 48
# index = 47 . Getting data of the StationId = 49
# index = 48 . Getting data of the StationId = 50
# index = 49 . Getting data of the StationId = 51
# index = 50 . Getting data of the StationId = 52
# index = 51 . Getting data of the StationId = 53
# index = 52 . Getting data of the StationId = 54
# index = 53 . Getting data of the StationId = 55
# index = 54 . Getting data of the StationId = 56
# index = 55 . Getting data of the StationId = 57
# index = 56 . Getting data of the StationId = 58
# index = 57 . Getting data of the StationId = 59
# index = 58 . Getting data of the StationId = 60
# No data of the stationID = 60 between 202006302359 and 202012312359
# index = 59 . Getting data of the StationId = 61
# index = 60 . Getting data of the StationId = 62
# index = 61 . Getting data of the StationId = 63
# index = 62 . Getting data of the StationId = 64
# index = 63 . Getting data of the StationId = 65
# index = 64 . Getting data of the StationId = 66
# index = 65 . Getting data of the StationId = 67
# index = 66 . Getting data of the StationId = 68
# index = 67 . Getting data of the StationId = 69
# index = 68 . Getting data of the StationId = 70
# No data of the stationID = 70 between 202006302359 and 202012312359
# index = 69 . Getting data of the StationId = 71
# index = 70 . Getting data of the StationId = 72
# index = 71 . Getting data of the StationId = 73
# index = 72 . Getting data of the StationId = 74
# index = 73 . Getting data of the StationId = 75
# index = 74 . Getting data of the StationId = 76
# index = 75 . Getting data of the StationId = 77
# index = 76 . Getting data of the StationId = 78
# index = 77 . Getting data of the StationId = 79
# index = 78 . Getting data of the StationId = 80
# index = 79 . Getting data of the StationId = 81
# index = 80 . Getting data of the StationId = 82
# index = 81 . Getting data of the StationId = 83
# index = 82 . Getting data of the StationId = 84
# index = 83 . Getting data of the StationId = 85
# index = 84 . Getting data of the StationId = 86
# index = 85 . Getting data of the StationId = 87
# index = 86 . Getting data of the StationId = 88
# index = 87 . Getting data of the StationId = 89
# index = 88 . Getting data of the StationId = 90
# index = 89 . Getting data of the StationId = 91
# index = 90 . Getting data of the StationId = 92
# index = 91 . Getting data of the StationId = 93
# index = 92 . Getting data of the StationId = 94
# index = 93 . Getting data of the StationId = 95
# index = 94 . Getting data of the StationId = 96
# index = 95 . Getting data of the StationId = 97
# index = 96 . Getting data of the StationId = 98
# index = 97 . Getting data of the StationId = 99
# index = 98 . Getting data of the StationId = 100
# index = 99 . Getting data of the StationId = 101
# index = 100 . Getting data of the StationId = 102
# index = 101 . Getting data of the StationId = 103
# index = 102 . Getting data of the StationId = 104
# index = 103 . Getting data of the StationId = 105
# index = 104 . Getting data of the StationId = 106
# index = 105 . Getting data of the StationId = 107
# index = 106 . Getting data of the StationId = 108
# index = 107 . Getting data of the StationId = 109
# index = 108 . Getting data of the StationId = 110
# index = 109 . Getting data of the StationId = 111
# index = 110 . Getting data of the StationId = 112
# index = 111 . Getting data of the StationId = 113
# index = 112 . Getting data of the StationId = 114
# index = 113 . Getting data of the StationId = 115
# index = 114 . Getting data of the StationId = 116
# index = 115 . Getting data of the StationId = 117

# %% [markdown]
# 2.4.3. Datasets of the Quarter 1 & 2 in 2021

# %%
# Get data from 01/01/2021 to 30/06/2021
dfrom = '202012312359'
dto = '202106302359'

df = getDataAllStations(stations_df, dfrom, dto)

# Save data into a file (It's stored in Google Drive for later analysis)
df.to_csv('drive/MyDrive/dublinbikes/datasets/dublinbikes_2021_Quarter_1_2.csv', index=False)
# Out:
# No data of the stationID = 1 between 202012312359 and 202106302359
# index = 1 . Getting data of the StationId = 2
# index = 2 . Getting data of the StationId = 3
# index = 3 . Getting data of the StationId = 4
# index = 4 . Getting data of the StationId = 5
# index = 5 . Getting data of the StationId = 6
# index = 6 . Getting data of the StationId = 7
# index = 7 . Getting data of the StationId = 8
# index = 8 . Getting data of the StationId = 9
# index = 9 . Getting data of the StationId = 10
# index = 10 . Getting data of the StationId = 11
# index = 11 . Getting data of the StationId = 12
# index = 12 . Getting data of the StationId = 13
# index = 13 . Getting data of the StationId = 14
# No data of the stationID = 14 between 202012312359 and 202106302359
# index = 14 . Getting data of the StationId = 15
# index = 15 . Getting data of the StationId = 16
# index = 16 . Getting data of the StationId = 17
# index = 17 . Getting data of the StationId = 18
# index = 18 . Getting data of the StationId = 19
# index = 19 . Getting data of the StationId = 21
# index = 20 . Getting data of the StationId = 22
# index = 21 . Getting data of the StationId = 23
# index = 22 . Getting data of the StationId = 24
# index = 23 . Getting data of the StationId = 25
# index = 24 . Getting data of the StationId = 26
# index = 25 . Getting data of the StationId = 27
# index = 26 . Getting data of the StationId = 28
# index = 27 . Getting data of the StationId = 29
# index = 28 . Getting data of the StationId = 30
# index = 29 . Getting data of the StationId = 31
# index = 30 . Getting data of the StationId = 32
# index = 31 . Getting data of the StationId = 33
# API time out. Retrying...
# index = 32 . Getting data of the StationId = 34
# index = 33 . Getting data of the StationId = 35
# No data of the stationID = 35 between 202012312359 and 202106302359
# index = 34 . Getting data of the StationId = 36
# index = 35 . Getting data of the StationId = 37
# index = 36 . Getting data of the StationId = 38
# index = 37 . Getting data of the StationId = 39
# index = 38 . Getting data of the StationId = 40
# index = 39 . Getting data of the StationId = 41
# index = 40 . Getting data of the StationId = 42
# index = 41 . Getting data of the StationId = 43
# index = 42 . Getting data of the StationId = 44
# index = 43 . Getting data of the StationId = 45
# index = 44 . Getting data of the StationId = 46
# No data of the stationID = 46 between 202012312359 and 202106302359
# index = 45 . Getting data of the StationId = 47
# index = 46 . Getting data of the StationId = 48
# index = 47 . Getting data of the StationId = 49
# index = 48 . Getting data of the StationId = 50
# index = 49 . Getting data of the StationId = 51
# index = 50 . Getting data of the StationId = 52
# index = 51 . Getting data of the StationId = 53
# index = 52 . Getting data of the StationId = 54
# index = 53 . Getting data of the StationId = 55
# index = 54 . Getting data of the StationId = 56
# index = 55 . Getting data of the StationId = 57
# index = 56 . Getting data of the StationId = 58
# index = 57 . Getting data of the StationId = 59
# index = 58 . Getting data of the StationId = 60
# No data of the stationID = 60 between 202012312359 and 202106302359
# index = 59 . Getting data of the StationId = 61
# index = 60 . Getting data of the StationId = 62
# index = 61 . Getting data of the StationId = 63
# index = 62 . Getting data of the StationId = 64
# index = 63 . Getting data of the StationId = 65
# index = 64 . Getting data of the StationId = 66
# index = 65 . Getting data of the StationId = 67
# index = 66 . Getting data of the StationId = 68
# index = 67 . Getting data of the StationId = 69
# index = 68 . Getting data of the StationId = 70
# No data of the stationID = 70 between 202012312359 and 202106302359
# index = 69 . Getting data of the StationId = 71
# index = 70 . Getting data of the StationId = 72
# index = 71 . Getting data of the StationId = 73
# index = 72 . Getting data of the StationId = 74
# index = 73 . Getting data of the StationId = 75
# index = 74 . Getting data of the StationId = 76
# index = 75 . Getting data of the StationId = 77
# index = 76 . Getting data of the StationId = 78
# index = 77 . Getting data of the StationId = 79
# index = 78 . Getting data of the StationId = 80
# index = 79 . Getting data of the StationId = 81
# No data of the stationID = 81 between 202012312359 and 202106302359
# index = 80 . Getting data of the StationId = 82
# index = 81 . Getting data of the StationId = 83
# index = 82 . Getting data of the StationId = 84
# index = 83 . Getting data of the StationId = 85
# index = 84 . Getting data of the StationId = 86
# index = 85 . Getting data of the StationId = 87
# index = 86 . Getting data of the StationId = 88
# index = 87 . Getting data of the StationId = 89
# index = 88 . Getting data of the StationId = 90
# index = 89 . Getting data of the StationId = 91
# index = 90 . Getting data of the StationId = 92
# index = 91 . Getting data of the StationId = 93
# index = 92 . Getting data of the StationId = 94
# index = 93 . Getting data of the StationId = 95
# index = 94 . Getting data of the StationId = 96
# index = 95 . Getting data of the StationId = 97
# index = 96 . Getting data of the StationId = 98
# index = 97 . Getting data of the StationId = 99
# index = 98 . Getting data of the StationId = 100
# index = 99 . Getting data of the StationId = 101
# index = 100 . Getting data of the StationId = 102
# index = 101 . Getting data of the StationId = 103
# index = 102 . Getting data of the StationId = 104
# index = 103 . Getting data of the StationId = 105
# index = 104 . Getting data of the StationId = 106
# index = 105 . Getting data of the StationId = 107
# index = 106 . Getting data of the StationId = 108
# index = 107 . Getting data of the StationId = 109
# index = 108 . Getting data of the StationId = 110
# index = 109 . Getting data of the StationId = 111
# index = 110 . Getting data of the StationId = 112
# index = 111 . Getting data of the StationId = 113
# index = 112 . Getting data of the StationId = 114
# index = 113 . Getting data of the StationId = 115
# index = 114 . Getting data of the StationId = 116
# index = 115 . Getting data of the StationId = 117
